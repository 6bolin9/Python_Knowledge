# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Categoricals-and-groupby" data-toc-modified-id="Categoricals-and-groupby-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Categoricals and groupby</a></span><ul class="toc-item"><li><span><a href="#建立DF--多种方法" data-toc-modified-id="建立DF--多种方法-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>建立DF--多种方法</a></span></li><li><span><a href="#Aggregation/reduction:count值--确定一个列的value后" data-toc-modified-id="Aggregation/reduction:count值--确定一个列的value后-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Aggregation/reduction:count值--确定一个列的value后</a></span><ul class="toc-item"><li><span><a href="#.groupby('列).count():先分类别，在计算每种的次数，再结合为DF" data-toc-modified-id=".groupby('列).count():先分类别，在计算每种的次数，再结合为DF-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>.groupby('列).count():先分类别，在计算每种的次数，再结合为DF</a></span></li><li><span><a href="#还可以groupby+mean().-std().-sum().-min().max.()" data-toc-modified-id="还可以groupby+mean().-std().-sum().-min().max.()-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>还可以groupby+mean(). std(). sum(). min().max.()</a></span></li></ul></li><li><span><a href="#weekday分组的bread+butter分别总和" data-toc-modified-id="weekday分组的bread+butter分别总和-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>weekday分组的bread+butter分别总和</a></span></li><li><span><a href="#多组的多个aggregation" data-toc-modified-id="多组的多个aggregation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>多组的多个aggregation</a></span><ul class="toc-item"><li><span><a href="#agg()后面可以加‘文字’；也能加入自己的function" data-toc-modified-id="agg()后面可以加‘文字’；也能加入自己的function-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>agg()后面可以加‘文字’；也能加入自己的function</a></span></li></ul></li><li><span><a href="#muti-level的groupby：也是引入一个【】" data-toc-modified-id="muti-level的groupby：也是引入一个【】-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>muti-level的groupby：也是引入一个【】</a></span><ul class="toc-item"><li><span><a href="#A列的种类-乘以-B类的种类-=-总的种数=group" data-toc-modified-id="A列的种类-乘以-B类的种类-=-总的种数=group-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>A列的种类 乘以 B类的种类 = 总的种数=group</a></span></li></ul></li></ul></li><li><span><a href="#DF-结合Pandas_series-使用groupby" data-toc-modified-id="DF-结合Pandas_series-使用groupby-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DF 结合Pandas_series 使用groupby</a></span></li><li><span><a href="#多组多列：multiple-aggregates-of-multiple-columns" data-toc-modified-id="多组多列：multiple-aggregates-of-multiple-columns-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>多组多列：multiple aggregates of multiple columns</a></span></li><li><span><a href="#读入数据就能对col分组" data-toc-modified-id="读入数据就能对col分组-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>读入数据就能对col分组</a></span><ul class="toc-item"><li><span><a href="#分组：index_col=['Year','region','Country'].sort_index()" data-toc-modified-id="分组：index_col=['Year','region','Country'].sort_index()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>分组：index_col=['Year','region','Country'].sort_index()</a></span></li></ul></li><li><span><a href="#自己function和内设function通过字典运用到.agg()" data-toc-modified-id="自己function和内设function通过字典运用到.agg()-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>自己function和内设function通过字典运用到.agg()</a></span></li><li><span><a href="#Categorical变量" data-toc-modified-id="Categorical变量-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Categorical变量</a></span><ul class="toc-item"><li><span><a href="#.unique()产生不同的entry" data-toc-modified-id=".unique()产生不同的entry-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>.unique()产生不同的entry</a></span></li></ul></li><li><span><a href="#Transformation:-Z-score" data-toc-modified-id="Transformation:-Z-score-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Transformation: Z-score</a></span><ul class="toc-item"><li><span><a href="#Detecting-outliers---Z-Scores" data-toc-modified-id="Detecting-outliers---Z-Scores-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Detecting outliers-- Z-Scores</a></span></li></ul></li><li><span><a href="#Fill-missing通过不同组" data-toc-modified-id="Fill-missing通过不同组-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Fill missing通过不同组</a></span><ul class="toc-item"><li><span><a href="#DF.groupby(['','','']).'需要填的col'.transform(own_function)" data-toc-modified-id="DF.groupby(['','','']).'需要填的col'.transform(own_function)-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>DF.groupby(['','','']).'需要填的col'.transform(own_function)</a></span></li><li><span><a href="#.apply()-method" data-toc-modified-id=".apply()-method-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>.apply() method</a></span><ul class="toc-item"><li><span><a href="#disparity-within-regions-of-the-world" data-toc-modified-id="disparity-within-regions-of-the-world-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>disparity within regions of the world</a></span></li></ul></li></ul></li><li><span><a href="#Filtering-Grouping-+-Filtering" data-toc-modified-id="Filtering-Grouping-+-Filtering-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Filtering Grouping + Filtering</a></span><ul class="toc-item"><li><span><a href="#Grouping-and-filtering-with-.filter()" data-toc-modified-id="Grouping-and-filtering-with-.filter()-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Grouping and filtering with .filter()</a></span></li><li><span><a href="#Filtering-and-grouping-with-.map()" data-toc-modified-id="Filtering-and-grouping-with-.map()-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Filtering and grouping with .map()</a></span></li></ul></li><li><span><a href="#案例：Summer-Olympics" data-toc-modified-id="案例：Summer-Olympics-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>案例：Summer Olympics</a></span><ul class="toc-item"><li><span><a href="#find-the-total-number-of-medals-awarded-to-the-USA-per-edition." data-toc-modified-id="find-the-total-number-of-medals-awarded-to-the-USA-per-edition.-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>find the total number of medals awarded to the USA per edition.</a></span></li><li><span><a href="#.value_counts()-for-ranking：列的不同值+排序" data-toc-modified-id=".value_counts()-for-ranking：列的不同值+排序-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>.value_counts() for ranking：列的不同值+排序</a></span></li><li><span><a href="#.pivot_table()-to-count-medals-by-type" data-toc-modified-id=".pivot_table()-to-count-medals-by-type-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>.pivot_table() to count medals by type</a></span></li><li><span><a href="#drop_duplicates和groupby()" data-toc-modified-id="drop_duplicates和groupby()-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>drop_duplicates和groupby()</a></span></li><li><span><a href="#根据条件filter数据" data-toc-modified-id="根据条件filter数据-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>根据条件filter数据</a></span></li></ul></li><li><span><a href="#案例.nunique()-不同值排列" data-toc-modified-id="案例.nunique()-不同值排列-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>案例.nunique() 不同值排列</a></span><ul class="toc-item"><li><span><a href="#aggregate-the-number-of-distinct-[sports]-in-which-the-[USA-and-the-USSR]-won-medals-[during-the-Cold-War-years]." data-toc-modified-id="aggregate-the-number-of-distinct-[sports]-in-which-the-[USA-and-the-USSR]-won-medals-[during-the-Cold-War-years].-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>aggregate the number of distinct [sports] in which the [USA and the USSR] won medals [during the Cold War years].</a></span></li></ul></li><li><span><a href="#案例-idxmin()-idxmax()-pivito" data-toc-modified-id="案例-idxmin()-idxmax()-pivito-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>案例 idxmin() idxmax() pivito</a></span></li><li><span><a href="#案例Visualizing" data-toc-modified-id="案例Visualizing-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>案例Visualizing</a></span><ul class="toc-item"><li><span><a href="#作图-USA-Medal-Counts-by-Edition:-Area-Plot" data-toc-modified-id="作图-USA-Medal-Counts-by-Edition:-Area-Plot-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>作图 USA Medal Counts by Edition: Area Plot</a></span></li><li><span><a href="#定义为categorical变量后作图" data-toc-modified-id="定义为categorical变量后作图-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>定义为categorical变量后作图</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Categoricals and groupby
# ## 建立DF--多种方法

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame (
                 {
                'weekday' : ['Sun','Sun','Mon','Mon'],
                 'City': ['Au', 'Da','Au', 'Das'] ,    
                'bread'   : [139, 237, 326, 456] , 
                'butter'  : [20,  20,  70,  98]
                     
                 }
                   )
print(df)
# Out:
#   City  bread  butter weekday
# 0   Au    139      20     Sun
# 1   Da    237      20     Sun
# 2   Au    326      70     Mon
# 3  Das    456      98     Mon

# %%
data = np.array([['','Col1','Col2'],
                ['Row1',1,2],
                ['Row2',3,4]])
                
df_array = pd.DataFrame(data=data[1:,1:],
                  index=data[1:,0],
                  columns=data[0,1:])
print(df_array)
# Out:
#      Col1 Col2
# Row1    1    2
# Row2    3    4

# %%
len(df['butter'])
# Out:
# 4

# %% [markdown]
# ## Aggregation/reduction:count值--确定一个列的value后
# ### .groupby('列).count():先分类别，在计算每种的次数，再结合为DF
# ### 还可以groupby+mean(). std(). sum(). min().max.()

# %%
df.loc[df['weekday'=='Sun']].count()

# %%
df.groupby('weekday').count()
# Out:
#          City  bread  butter
# weekday
# Mon         2      2       2
# Sun         2      2       2

# %%
df.groupby('weekday').mean()
# Out:
#          bread  butter
# weekday
# Mon      391.0    84.0
# Sun      188.0    32.5

# %%
df.groupby('weekday').std()
# Out:
#              bread    butter
# weekday
# Mon      91.923882  19.79899
# Sun      69.296465  17.67767

# %%
df.groupby('weekday').min()
# Out:
#         City  bread  butter
# weekday
# Mon       Au    326      70
# Sun       Au    139      20

# %%
df.groupby('weekday').max()
# Out:
#         City  bread  butter
# weekday
# Mon       Da    456      98
# Sun       Da    237      45

# %% [markdown]
# ## weekday分组的bread+butter分别总和

# %%
#单个【】
df.groupby('weekday')['bread'].sum()
# Out:
# weekday
# Mon    782
# Sun    376
# Name: bread, dtype: int64

# %%
#两个【】，是list
df.groupby('weekday')[['bread','butter']].sum()
# Out:
#          bread  butter
# weekday
# Mon        782     168
# Sun        376      65

# %% [markdown]
# ## 多组的多个aggregation
# ### agg()后面可以加‘文字’；也能加入自己的function

# %%
#多分组+多个aggregation
df.groupby('City')[['bread','butter']].agg(['min','max','sum'])
# Out:
#      bread           butter
#        min  max  sum    min max  sum
# City
# Au     139  326  465     20  70   90
# Da     237  456  693     45  98  143

# %%
#自己定义 function + 应用到agg()中
def data_range(series):
    return series.max() - series.min()

# %%
#运用自己的function
df.groupby('City')[['bread','butter']].agg([data_range])
# Out:
#           bread     butter
#      data_range data_range
# City
# Au          187         50
# Da          219         53

# %% [markdown]
# ## muti-level的groupby：也是引入一个【】
# ### A列的种类 乘以 B类的种类 = 总的种数=group

# %%
df.groupby(['weekday','City']).sum()
# Out:
#               bread  butter
# weekday City
# Mon     Au      326      70
#         Da      456      98
# Sun     Au      139      20
#         Da      237      45

# %% [markdown]
# # DF 结合Pandas_series 使用groupby

# %%
customers = pd.Series(['A','B','C'])
customers
# Out:
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
df
# Out:
#   City  bread  butter weekday
# 0   Au    139      20     Sun
# 1   Da    237      45     Sun
# 2   Au    326      70     Mon
# 3   Da    456      98     Mon

# %%
df.groupby(customers)['bread'].sum()
# Out:
# A    139
# B    237
# C    326
# Name: bread, dtype: int64

# %%
# Read life_fname into a DataFrame: life
life = pd.read_csv(life_fname, index_col='Country')

# Read regions_fname into a DataFrame: regions
regions = pd.read_csv(regions_fname, index_col='Country')

# Group life by regions['region']: life_by_region
life_by_region = life.groupby(regions['region'])

# Print the mean over the '2010' column of life_by_region
print(life_by_region['2010'].mean())

# %% [markdown]
# # 多组多列：multiple aggregates of multiple columns

# %%
titanic = pd.read_csv('/Users/libolin/Downloads/titanic.csv')

# %%
#1.df是泰坦尼克号---先分组通过'pclass'作为row的分组
by_class = titanic.groupby('pclass')

# 2.在选择其中的两个变量为列：Select 'age' and 'fare'
by_class_sub = by_class[['age','fare']]

#3. 再求aggregation的值：分组按照pclass 分列按照'age','fare'，显示最大值和median
# Aggregate by_class_sub by 'max' and 'median': aggregated
aggregated = by_class_sub.agg(['max','median'])

# %%
#4.只要看'age','max'的全部行 Print the maximum age in each class
print(aggregated.loc[:, ('age','max')])

#5.只要看'fare','median'的全部行 Print the median fare in each class
print(aggregated.loc[:, ('fare','median')])
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: (age, max), dtype: float64
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: (fare, median), dtype: float64

# %%
#自己定义的function
年龄段=by_class_sub.agg([data_range])
年龄段
# Out:
#               age       fare
#        data_range data_range
# pclass
# 1           79.08   512.3292
# 2           69.33    73.5000
# 3           73.83    69.5500

# %%
年龄大小=by_class_sub.agg(['max','min'])
年龄大小
# Out:
#          age            fare
#          max   min       max  min
# pclass
# 1       80.0  0.92  512.3292  0.0
# 2       70.0  0.67   73.5000  0.0
# 3       74.0  0.17   69.5500  0.0

# %%
#普通的读入文件CSV
gapminder1 = pd.read_csv('/Users/libolin/Downloads/gapminder_tidy.csv')
gapminder1.head(5)
# Out:
#        Country  Year  fertility    life  population  child_mortality     gdp  \
# 0  Afghanistan  1964      7.671  33.639  10474903.0            339.7  1182.0
# 1  Afghanistan  1965      7.671  34.152  10697983.0            334.1  1182.0
# 2  Afghanistan  1966      7.671  34.662  10927724.0            328.7  1168.0
# 3  Afghanistan  1967      7.671  35.170  11163656.0            323.3  1173.0
# 4  Afghanistan  1968      7.671  35.674  11411022.0            318.1  1187.0
#
#        region
# 0  South Asia
# 1  South Asia
# 2  South Asia
# 3  South Asia
# 4  South Asia

# %% [markdown]
# # 读入数据就能对col分组
# ## 分组：index_col=['Year','region','Country'].sort_index()

# %%
# Read the CSV file into a DataFrame and sort the index: gapminder
gapminder = pd.read_csv('/Users/libolin/Downloads/gapminder_tidy.csv', 
                        index_col=['Year','region','Country']).sort_index()
gapminder.head()
# Out:
#                                   fertility    life  population  \
# Year region  Country
# 1964 America Antigua and Barbuda      4.250  63.775     58653.0
#              Argentina                3.068  65.388  21966478.0
#              Aruba                    4.059  67.113     57031.0
#              Bahamas                  4.220  64.189    133709.0
#              Barbados                 4.094  62.819    234455.0
#
#                                   child_mortality      gdp
# Year region  Country
# 1964 America Antigua and Barbuda            72.78   5008.0
#              Argentina                      57.43   8227.0
#              Aruba                            NaN   5505.0
#              Bahamas                        48.56  18160.0
#              Barbados                       64.70   5681.0

# %%
# 再分组：Group gapminder by 'Year' and 'region': by_year_region
by_year_region = gapminder.groupby(level=['Year','region'])
by_year_region.head(6)
# Out:
#                                                      fertility      life  \
# Year region                     Country
# 1964 America                    Antigua and Barbuda      4.250  63.77500
#                                 Argentina                3.068  65.38800
#                                 Aruba                    4.059  67.11300
#                                 Bahamas                  4.220  64.18900
#                                 Barbados                 4.094  62.81900
#                                 Belize                   6.420  62.24100
#      East Asia & Pacific        Australia                3.154  70.65000
#                                 Brunei                   6.227  64.59900
#                                 Cambodia                 6.909  41.90000
#                                 China                    6.120  53.32072
#                                 Fiji                     5.676  57.54500
# ...

# %% [markdown]
# # 自己function和内设function通过字典运用到.agg()

# %%
# 1.自己定义方程Define the function to compute spread: spread
def spread(series):
    return series.max() - series.min()

# 2.自己的对每种列的对应计算的aggregation的字典： Create the dictionary: aggregator
aggregator = {'population':'sum', 'child_mortality':'mean', 'gdp':spread}

# 3.将字典运用到agg(里面)：Aggregate by_year_region using the dictionary: aggregated
aggregated = by_year_region.agg(aggregator)

# Print the last 6 entries of aggregated 
print(aggregated.tail(6))
# Out:
#                                    population  child_mortality       gdp
# Year region
# 2013 America                     9.629087e+08        17.745833   49634.0
#      East Asia & Pacific         2.244209e+09        22.285714  134744.0
#      Europe & Central Asia       8.968788e+08         9.831875   86418.0
#      Middle East & North Africa  4.030504e+08        20.221500  128676.0
#      South Asia                  1.701241e+09        46.287500   11469.0
#      Sub-Saharan Africa          9.205996e+08        76.944490   32035.0

# %%
# 1.读入文件，按照日期作为行的index，并且排序理解。Read file: sales
sales = pd.read_csv('/Users/libolin/Downloads/sales/sales-feb-2015.csv', index_col='Date', parse_dates=True)
sales
# Out:
#                              Company   Product  Units
# Date
# 2015-02-02 08:30:00            Hooli  Software      3
# 2015-02-02 21:00:00        Mediacore  Hardware      9
# 2015-02-03 14:00:00          Initech  Software     13
# 2015-02-04 15:30:00        Streeplex  Software     13
# 2015-02-04 22:00:00  Acme Coporation  Hardware     14
# 2015-02-05 02:00:00  Acme Coporation  Software     19
# 2015-02-05 22:00:00            Hooli   Service     10
# 2015-02-07 23:00:00  Acme Coporation  Hardware      1
# 2015-02-09 09:00:00        Streeplex   Service     19
# 2015-02-09 13:00:00        Mediacore  Software      7
# 2015-02-11 20:00:00          Initech  Software      7
# 2015-02-11 23:00:00            Hooli  Software      4
# 2015-02-16 12:00:00            Hooli  Software     10
# 2015-02-19 11:00:00        Mediacore  Hardware     16
# 2015-02-19 16:00:00        Mediacore   Service     10
# 2015-02-21 05:00:00        Mediacore  Software      3
# ...

# %%
# 创立新的Create a groupby object--根据： sales.index.strftime('%a') as input and assign it to by_day
#Create a groupby object: by_day：改编成星期了
by_day = sales.groupby(sales.index.strftime('%a'))
# 求DF其中已经有的units列的总和：Create sum: units_sum
units_sum = by_day['Units'].sum()

# Print units_sum
print(units_sum)
# Out:
# Mon    48
# Sat     7
# Thu    59
# Tue    13
# Wed    48
# Name: Units, dtype: int64

# %%
sales.groupby(sales.index.strftime('%a')).count()
# Out:
#      Company  Product  Units
# Mon        5        5      5
# Sat        3        3      3
# Thu        5        5      5
# Tue        1        1      1
# Wed        5        5      5

# %% [markdown]
# # Categorical变量
# ## .unique()产生不同的entry

# %% [markdown]
# # Transformation: Z-score
# ## Detecting outliers-- Z-Scores
# - 建立Zscore function
# - 针对DF的column进行处理转化:zscore(df['col'])
# - 有的时候要根据group去transform
#    - DF.groupby('year')['col'].transfrom(zscore)

# %%
# Import zscore
from scipy.stats import zscore

# %%
# Group gapminder_2010: standardized
standardized = gapminder.groupby('region')['life','fertility'].transform(zscore)

# Construct a Boolean Series to identify outliers: outliers
outliers = (standardized['life'] < -3) | (standardized['fertility'] > 3)

# Filter gapminder_2010 by the outliers: gm_outliers
gm_outliers = gapminder.loc[outliers]
gm_outliers
# Out:
#                                               fertility    life  population  \
# Year region                     Country
# 1964 America                    Bolivia           6.607  43.913   3668568.0
#                                 Guatemala         6.434  47.884   4636016.0
#                                 Haiti             6.233  44.464   4188276.0
#      East Asia & Pacific        Timor-Leste       6.347  35.724    537278.0
#      Europe & Central Asia      Turkey            6.029  48.313  31109820.0
#                                 Turkmenistan      6.663  56.181   1829697.0
#      Middle East & North Africa Yemen, Rep.       7.385  36.068   5527652.0
# 1965 America                    Bolivia           6.593  44.229   3752892.0
#                                 Haiti             6.179  45.006   4272760.0
#      East Asia & Pacific        Timor-Leste       6.314  36.263    547681.0
#      Europe & Central Asia      Turkey            5.951  49.037  31837999.0
# ...

# %% [markdown]
# # Fill missing通过不同组
# ## DF.groupby(['','','']).'需要填的col'.transform(own_function)
# ** Imputing missing values intelligently is always preferrable to dropping them entirely!**

# %%
# 通过对性别和船票的等级分组
#Create a groupby object: by_sex_class
by_sex_class = titanic.groupby(['sex','pclass'])

# 写出一个填写median的表达式方程
#Write a function that imputes median
def impute_median(series):
    return series.fillna(series.median())

# 针对每一种class填写入median
#Impute age and assign to titanic.age
titanic.age = by_sex_class.age.transform(impute_median)

# Print the output of titanic.tail(10)
print(titanic.tail(10))
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female  15.0
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male  25.0
# 1303       3         0                    Yousseff, Mr. Gerious    male  25.0
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female  22.0
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                       Zimmerman, Mr. Leo    male  29.0
#
#       sibsp  parch  ticket     fare cabin embarked boat   body home.dest
# ...

# %% [markdown]
# ## .apply() method
# - Use when used on a groupby object performs an arbitrary function on each of the groups.
# - These functions can be aggregations, transformations or more complex workflows.
#
#
#  ### disparity within regions of the world
#   - define a function to compute the aggregate spread of per capita GDP in each region
#   - and the individual country's z-score of the regional per capita GDP.
#   - select three countries - United States, Great Britain and China - to see a summary of the regional GDP and that country's z-score against the regional mean.

# %%
def disparity(gr):
    # Compute the spread of gr['gdp']: s
    s = gr['gdp'].max() - gr['gdp'].min()
    # Compute the z-score of gr['gdp'] as (gr['gdp']-gr['gdp'].mean())/gr['gdp'].std(): z
    z = (gr['gdp'] - gr['gdp'].mean())/gr['gdp'].std()
    # Return a DataFrame with the inputs {'z(gdp)':z, 'regional spread(gdp)':s}
    return pd.DataFrame({'z(gdp)':z , 'regional spread(gdp)':s})

# %%
# Group gapminder_2010 by 'region': regional
regional = gapminder.groupby('region')

# Apply the disparity function on regional: reg_disp
reg_disp = regional.apply(disparity)

# Print the disparity of 'United States', 'United Kingdom', and 'China'
print(reg_disp.loc[['United States','United Kingdom','China']])

# %% [markdown]
# # Filtering Grouping + Filtering
# - 1.先filter数据---寻求目标数据“目标：车名/姓氏等”
#
# - 2.Group数据 + 求这个group的一些统计数据
#
# **take the Titanic data set and analyze survival rates from the 'C' deck,** which contained the most passengers.
#
# - To do this you'll group the dataset by 'sex'
# - and then use the .apply() method on a provided user defined function
#    - which calculates the mean survival rates on the 'C' deck:

# %%
def c_deck_survival(gr):

    c_passengers = gr['cabin'].str.startswith('C').fillna(False)

    return gr.loc[c_passengers, 'survived'].mean()

# %%
# Create a groupby object using titanic over the 'sex' column: by_sex
by_sex = titanic.groupby('sex')

# Call by_sex.apply with the function c_deck_survival and print the result
c_surv_by_sex = by_sex.apply(c_deck_survival)

# Print the survival rates
print(c_surv_by_sex)
# Out:
# sex
# female    0.913043
# male      0.312500
# dtype: float64

# %% [markdown]
# ## Grouping and filtering with .filter()
# - identify how many units each company bought for verification.
# - Next you'll use the .filter() method after grouping by 'Company'
#    - to remove all rows belonging to companies whose sum over the 'Units' column was less than 35.
# - Finally, verify that the three companies whose total Units purchased were less than 35 have been filtered out from the DataFrame.

# %%
#data frame : sales
# Group sales by 'Company': by_company
by_company = sales.groupby('Company')

# Compute the sum of the 'Units' of by_company: by_com_sum
by_com_sum = by_company['Units'].sum()
print(by_com_sum)

# Filter 'Units' where the sum is > 35: by_com_filt
by_com_filt = by_company.filter(lambda g:g['Units'].sum() > 35)
print(by_com_filt)
# Out:
# Company
# Acme Coporation    34
# Hooli              30
# Initech            30
# Mediacore          45
# Streeplex          36
# Name: Units, dtype: int64
#                        Company   Product  Units
# Date
# 2015-02-02 21:00:00  Mediacore  Hardware      9
# 2015-02-04 15:30:00  Streeplex  Software     13
# 2015-02-09 09:00:00  Streeplex   Service     19
# 2015-02-09 13:00:00  Mediacore  Software      7
# 2015-02-19 11:00:00  Mediacore  Hardware     16
# 2015-02-19 16:00:00  Mediacore   Service     10
# 2015-02-21 05:00:00  Mediacore  Software      3
# 2015-02-26 09:00:00  Streeplex   Service      4

# %% [markdown]
# ## Filtering and grouping with .map()
#
# You have seen how to group by a column, or by multiple columns.
# Sometimes, you may instead want to group by a function/transformation of a column.
# - **The key here is that the Series is indexed the same way as the DataFrame. You can also mix and match column grouping with Series grouping.**
#
#    Investigate survival rates of passengers on the Titanic by 'age' and 'pclass'.
#    **to find out what fraction of children under 10 survived in each 'pclass'. **
#    - first creating a boolean array where True is passengers under 10 years old and False is passengers over 10.
#    - You'll use .map() to change these values to strings.
#
#    - Finally, group by the under 10 series and the 'pclass' column and aggregate the 'survived' column.
#
# **The 'survived' column has the value 1 if the passenger survived and 0 otherwise. The mean of the 'survived' column is the fraction of passengers who lived.**

# %%
#找出年龄小于10的所有rows
titanic[titanic['age'] < 10].head()
# Out:
#      pclass  survived                             name     sex   age  sibsp  \
# 1         1         1   Allison, Master. Hudson Trevor    male  0.92      1
# 2         1         0     Allison, Miss. Helen Loraine  female  2.00      1
# 94        1         1        Dodge, Master. Washington    male  4.00      0
# 273       1         1  Spedden, Master. Robert Douglas    male  6.00      0
# 339       2         1        Becker, Master. Richard F    male  1.00      2
#
#      parch  ticket      fare    cabin embarked boat  body  \
# 1        2  113781  151.5500  C22 C26        S   11   NaN
# 2        2  113781  151.5500  C22 C26        S  NaN   NaN
# 94       2   33638   81.8583      A34        S    5   NaN
# 273      2   16966  134.5000      E34        C    3   NaN
# 339      1  230136   39.0000       F4        S   11   NaN
#
#                               home.dest
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# ...

# %%
#针对是否小于10---用map进行：True or false ！！！针对numeric变量的分组处理
# Create the Boolean Series: under10
under10 = (titanic['age'] < 10).map({True:'under 10', False:'over 10'})

# %%
#分组出rows中(根据是否age<10)， 且计算其中的survival变量的平均值---就是rate
# Group by under10 and compute the survival rate
survived_mean_1 = titanic.groupby(under10)['survived'].mean()
print(survived_mean_1)
# Out:
# age
# over 10     0.366748
# under 10    0.609756
# Name: survived, dtype: float64

# %%
#涉及两个变量的分组 under10, 'pclass' 再计算aggregation
# Group by under10 and pclass and compute the survival rate
survived_mean_2 = titanic.groupby([under10, 'pclass'])['survived'].mean()
print(survived_mean_2)
# Out:
# age       pclass
# over 10   1         0.617555
#           2         0.380392
#           3         0.238897
# under 10  1         0.750000
#           2         1.000000
#           3         0.446429
# Name: survived, dtype: float64

# %% [markdown]
# # 案例：Summer Olympics
# - pattern 基本统计值
# - indexting 1 or muti
# - pivot_table()去reshape 数据集
# - groupby(), unique(), value_counts()
# - Aggregation, transformation, filtering

# %%
medals = pd.read_csv("/Users/libolin/Downloads/all_medalists.csv")
print(medals.head())
print(medals.info())
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# ...

# %% [markdown]
# ## find the total number of medals awarded to the USA per edition.
# - To do this, filter the 'USA' rows and
# - use the groupby() function to put the 'Edition' column on the index:

# %%
#dataframe是medals
#1.挑选出了 NOC列=USA的所有列，并用‘Edition’分组 
USA_edition_grouped = medals.loc[medals.NOC == 'USA'].groupby('Edition')

# %%
USA_edition_grouped

# %%
#2.只针对其中的‘Medal’列进行计算
USA_edition_grouped['Medal'].count()

# 得出了 NOC=USA 的 每个Edition的 Medal的 count
# Out:
# Edition
# 1896     20
# 1900     55
# 1904    394
# 1908     63
# 1912    101
# 1920    193
# 1924    198
# 1928     84
# 1932    181
# 1936     92
# 1948    148
# 1952    130
# 1956    118
# 1960    112
# 1964    150
# 1968    149
# 1972    155
# 1976    155
# 1984    333
# 1988    193
# 1992    224
# 1996    260
# 2000    248
# 2004    264
# 2008    315
# Name: Medal, dtype: int64

# %% [markdown]
# ## .value_counts() for ranking：列的不同值+排序
# - unique entries with values (counts) ranked in descending order.

# %%
#1.提取一列：# Select the 'NOC' column of medals: country_names
country_names = medals['NOC']
type(country_names)#针对的是DF中提取的series
# Out:
# pandas.core.series.Series

# %%
# Count the number of medals won by each country: medal_counts
medal_counts = country_names.value_counts()

# %%
# Print top 15 countries ranked by medals
print(medal_counts.head(5))
# Out:
# USA    4335
# URS    2049
# GBR    1594
# FRA    1314
# ITA    1228
# Name: NOC, dtype: int64

# %% [markdown]
# ## .pivot_table() to count medals by type
# - Use a pivot table to compute how many separate bronze, silver and gold medals each country won？
#
# **Construct a pivot table counted from the DataFrame medals aggregating by count. Use 'NOC' as the index, 'Athlete' for the values, and 'Medal' for the columns.**
#
# - index:什么变量作为行
# - values：什么变量作为数值value
# - columns：什么变量作为列出现
# - aggfunc: 求的是作为value 的什么统计学式子

# %%
# 1.填充：Construct the pivot table: counted
counted = medals.pivot_table(index='NOC', values='Athlete', 
                             columns='Medal', aggfunc='count')

# %%
counted.head() #这里的value是代表Athlete的个数
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG       1.0   NaN     NaN
# AHO       NaN   NaN     1.0
# ALG       8.0   4.0     2.0
# ANZ       5.0  20.0     4.0
# ARG      88.0  68.0    83.0

# %%
# 2：加入新的列-值是total：Create the new column: counted['totals']
counted['totals'] = counted.sum(axis='columns')#将这个DF的每个列求和
counted.head()#多了一个total列
# Out:
# Medal  Bronze  Gold  Silver  totals
# NOC
# AFG       1.0   NaN     NaN     2.0
# AHO       NaN   NaN     1.0     2.0
# ALG       8.0   4.0     2.0    28.0
# ANZ       5.0  20.0     4.0    58.0
# ARG      88.0  68.0    83.0   478.0

# %%
# Create the new column: counted['totals']
counted['x'] = counted.sum(axis=1)#好像只能对每列求和
counted.head()#多了一个total列
# Out:
# Medal  Bronze  Gold  Silver  totals  新行      x
# NOC
# AFG       1.0   NaN     NaN     2.0 NaN    3.0
# AHO       NaN   NaN     1.0     2.0 NaN    3.0
# ALG       8.0   4.0     2.0    28.0 NaN   42.0
# ANZ       5.0  20.0     4.0    58.0 NaN   87.0
# ARG      88.0  68.0    83.0   478.0 NaN  717.0

# %%
# 根据一个列的大小排列.sort_values('totals', ascending=False)由大到小
#Sort counted by the 'totals' column
counted = counted.sort_values('totals', ascending=False)
counted.head()
# Out:
# Medal  Bronze    Gold  Silver  totals  新行        x
# NOC
# USA    1052.0  2088.0  1195.0  8670.0 NaN  13005.0
# URS     584.0   838.0   627.0  4098.0 NaN   6147.0
# GBR     505.0   498.0   591.0  3188.0 NaN   4782.0
# FRA     475.0   378.0   461.0  2628.0 NaN   3942.0
# ITA     374.0   460.0   394.0  2456.0 NaN   3684.0

# %%
sum = medals.pivot_table(index='NOC', values='Athlete', 
                             columns='Medal', aggfunc='sum')

# %%
sum.head() #这里的value变成了所有Athlete名字加到一起
# Out:
# Medal                                             Bronze  \
# NOC
# AFG                                     NIKPAI, Rohullah
# AHO                                                 None
# ALG    ZAOUI, MohamedMOUSSA, MustaphaSOLTANI, HocineB...
# ANZ    BEAUREPAIRE, Frank E.KERR, Harry E.HARDWICK, H...
# ARG    PORZIO, AlfredoQUARTUCCI, PedroANGANUZZI, Raul...
#
# Medal                                               Gold  \
# NOC
# AFG                                                 None
# AHO                                                 None
# ALG    BOULMERKA, HassibaMORCELI, NourredineSOLTANI, ...
# ANZ    BARNETT, JumboBEDE-SMITH, FrankCARMICHAEL, Phi...
# ARG    KENNY, ArturoMILES, JuanNAYLOR, GuillermoNELSO...
#
# Medal                                             Silver
# NOC
# AFG                                                 None
# AHO                                      BOERSMA, Jan D.
# ALG                       SAIDI-SIEF, AliBENIKHLEF, Amar
# ...

# %% [markdown]
# ## drop_duplicates和groupby()

# %%
# 1.选择两列：两个方括号：Select columns: ev_gen----还是dataframe
ev_gen = medals[['Event_gender', 'Gender']]
type(ev_gen)
# Out:
# pandas.core.frame.DataFrame

# %%
#2.两列的总数据
ev_gen.shape
# Out:
# (29216, 2)

# %%
#3.去掉了重复的只剩下所有不一样的，Drop duplicate pairs: ev_gen_uniques
ev_gen_uniques = ev_gen.drop_duplicates()
ev_gen_uniques.shape
# Out:
# (5, 2)

# %%
#4.这两列组合的所有种类
ev_gen_uniques
# Out:
#       Event_gender Gender
# 0                M    Men
# 348              X    Men
# 416              W  Women
# 639              X  Women
# 23675            W    Men

# %%
#Finding possible errors with .groupby()
# 1.按照什么分组--2列5种组 Group medals by the two columns: medals_by_gender
medals_by_gender = medals.groupby(['Event_gender', 'Gender'])
# 2.分组里面要填充的是什么？count
# Create a DataFrame with a group count: medal_count_by_gender
medal_count_by_gender = medals_by_gender.count()
medal_count_by_gender.head()
# Out:
#                       City  Edition  Sport  Discipline  Athlete    NOC  Event  \
# Event_gender Gender
# M            Men     20067    20067  20067       20067    20067  20067  20067
# W            Men         1        1      1           1        1      1      1
#              Women    7277     7277   7277        7277     7277   7277   7277
# X            Men      1653     1653   1653        1653     1653   1653   1653
#              Women     218      218    218         218      218    218    218
#
#                      Medal
# Event_gender Gender
# M            Men     20067
# W            Men         1
#              Women    7277
# X            Men      1653
#              Women     218

# %% [markdown]
# ## 根据条件filter数据

# %%
# 1.两个条件的seies:Create the Boolean Series: sus
sus = (medals.Event_gender == 'W') & (medals.Gender == 'Men')

# %%
# 2.df[series(sus)]就是filter后的数据
suspect = medals[sus] 
suspect
# Out:
#          City  Edition      Sport Discipline            Athlete  NOC Gender  \
# 23675  Sydney     2000  Athletics  Athletics  CHEPCHUMBA, Joyce  KEN    Men
#
#           Event Event_gender   Medal
# 23675  marathon            W  Bronze

# %%
medals[(medals.Event_gender == 'W') & (medals.Gender == 'Men')]
# Out:
#          City  Edition      Sport Discipline            Athlete  NOC Gender  \
# 23675  Sydney     2000  Athletics  Athletics  CHEPCHUMBA, Joyce  KEN    Men
#
#           Event Event_gender   Medal
# 23675  marathon            W  Bronze

# %% [markdown]
# # 案例.nunique() 不同值排列

# %%
#1.根据一列分组： Group medals by 'NOC': country_grouped
country_grouped = medals.groupby('NOC')

# 2.分组后的根据另一列求不同值
#Compute the number of distinct sports in which each country won medals: Nsports
Nsports = country_grouped['Sport'].nunique()
Nsports.head()
# Out:
# NOC
# AFG     1
# AHO     1
# ALG     3
# ANZ     5
# ARG    17
# Name: Sport, dtype: int64

# %%
# 3.再由大到小排列不同值Sort the values of Nsports in descending order
Nsports = Nsports.sort_values(ascending=False)
# Print the top 15 rows of Nsports
print(Nsports.head(15))
# Out:
# NOC
# USA    34
# GBR    31
# FRA    28
# GER    26
# CHN    24
# AUS    22
# ESP    22
# CAN    22
# SWE    21
# URS    21
# ITA    21
# NED    20
# RUS    20
# JPN    20
# POL    19
# Name: Sport, dtype: int64

# %% [markdown]
# ## aggregate the number of distinct [sports] in which the [USA and the USSR] won medals [during the Cold War years].
#
# - 1.The Olympic competitions between 1952 and 1988
# - 2.between the United States of America (USA) & the Union of Soviet Socialist Republics (USSR)
# - 3.分组.groupby('NOC')
# - 4.Extract the column 'Sport'.
# - 5.Use .nunique() to get the number of unique elements in each group;
# - 6.Apply .sort_values(ascending=False) to rearrange the Series.

# %%
# 1.锁定时间段的rows：Extract all rows for which the 'Edition' is between 1952 & 1988: during_cold_war
during_cold_war = (medals.Edition>=1952) & (medals.Edition<=1988)

# 2.锁定国家两个列：在两个或者多个国家之间，用了:DF.国家.isin(['USA', 'URS'])
#Extract rows for which 'NOC' is either 'USA' or 'URS': is_usa_urs
is_usa_urs = medals.NOC.isin(['USA', 'URS'])

# 3.再把之前的两个条件并列再加上   df.loc[]      就能够提取了
#Use during_cold_war and is_usa_urs to create the DataFrame: cold_war_medals
cold_war_medals = medals.loc[during_cold_war & is_usa_urs]

# 4.在结果的基础上分组--根据一个列：Group cold_war_medals by 'NOC'
country_grouped = cold_war_medals.groupby('NOC')

# Create Nsports
Nsports = country_grouped['Sport'].nunique().sort_values(ascending=False)

# Print Nsports
print(Nsports)
# Out:
# NOC
# URS    21
# USA    20
# Name: Sport, dtype: int64

# %% [markdown]
# # 案例 idxmin() idxmax() pivito
# - Construct medals_won_by_country using medals.pivot_table().
#    - years ('Edition')
#    - & the columns should be country ('NOC')
#    - values should be 'Athlete' (which captures every medal regardless of kind)    - & the aggregation method should be 'count' (which captures the total number of medals won).

# %%
# 1.建立table：Create the pivot table: medals_won_by_country
medals_won_by_country = medals.pivot_table(index='Edition', columns='NOC', 
                                           values='Athlete', aggfunc='count')

# %%
medals_won_by_country.head()
# Out:
# NOC      AFG  AHO  ALG   ANZ  ARG  ARM  AUS   AUT  AZE  BAH  ...   URS  URU  \
# Edition                                                      ...
# 1896     NaN  NaN  NaN   NaN  NaN  NaN  2.0   5.0  NaN  NaN  ...   NaN  NaN
# 1900     NaN  NaN  NaN   NaN  NaN  NaN  5.0   6.0  NaN  NaN  ...   NaN  NaN
# 1904     NaN  NaN  NaN   NaN  NaN  NaN  NaN   1.0  NaN  NaN  ...   NaN  NaN
# 1908     NaN  NaN  NaN  19.0  NaN  NaN  NaN   1.0  NaN  NaN  ...   NaN  NaN
# 1912     NaN  NaN  NaN  10.0  NaN  NaN  NaN  14.0  NaN  NaN  ...   NaN  NaN
#
# NOC        USA  UZB  VEN  VIE  YUG  ZAM  ZIM   ZZX
# Edition
# 1896      20.0  NaN  NaN  NaN  NaN  NaN  NaN   6.0
# 1900      55.0  NaN  NaN  NaN  NaN  NaN  NaN  34.0
# 1904     394.0  NaN  NaN  NaN  NaN  NaN  NaN   8.0
# 1908      63.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 1912     101.0  NaN  NaN  NaN  NaN  NaN  NaN   NaN
#
# [5 rows x 138 columns]

# %%
#2. 选择行和列，按照.loc的方式：Slice medals_won_by_country: cold_war_usa_usr_medals
cold_war_usa_usr_medals = medals_won_by_country.loc[1952:1988, ['USA','URS']]
cold_war_usa_usr_medals
# Out:
# NOC        USA    URS
# Edition
# 1952     130.0  117.0
# 1956     118.0  169.0
# 1960     112.0  169.0
# 1964     150.0  174.0
# 1968     149.0  188.0
# 1972     155.0  211.0
# 1976     155.0  285.0
# 1980       NaN  442.0
# 1984     333.0    NaN
# 1988     193.0  294.0

# %%
# 3.比较两个列之间谁大，谁大就是谁+1:Create most_medals
most_medals = cold_war_usa_usr_medals.idxmax(axis='columns')
most_medals
# Out:
# Edition
# 1952    USA
# 1956    URS
# 1960    URS
# 1964    URS
# 1968    URS
# 1972    URS
# 1976    URS
# 1980    URS
# 1984    USA
# 1988    URS
# dtype: object

# %%
most_medals.value_counts()
# Out:
# URS    8
# USA    2
# dtype: int64

# %% [markdown]
# # 案例Visualizing

# %%
##1.新建的dataframe！！！
# Create the DataFrame: usa
usa = medals[medals.NOC == 'USA']
usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4335 entries, 11 to 29209
# Data columns (total 10 columns):
# City            4335 non-null object
# Edition         4335 non-null int64
# Sport           4335 non-null object
# Discipline      4335 non-null object
# Athlete         4335 non-null object
# NOC             4335 non-null object
# Gender          4335 non-null object
# Event           4335 non-null object
# Event_gender    4335 non-null object
# Medal           4335 non-null object
# dtypes: int64(1), object(9)
# memory usage: 372.5+ KB

# %%
# 2.根据两个列分组+求一个列的数量：
#Group usa by ['Edition', 'Medal'] and aggregate over 'Athlete'
usa_medals_by_year = usa.groupby(['Edition', 'Medal'])['Athlete'].count()
type(usa_medals_by_year)
usa_medals_by_year[1:10]
# Out:
# Edition  Medal
# 1896     Gold       11
#          Silver      7
# 1900     Bronze     14
#          Gold       27
#          Silver     14
# 1904     Bronze    111
#          Gold      146
#          Silver    137
# 1908     Bronze     15
# Name: Athlete, dtype: int64

# %%
#3. 将列medal的三种全部放到列中 
#.unstack(level='Medal')Reshape usa_medals_by_year by unstacking
usa_medals_by_year = usa_medals_by_year.unstack(level='Medal')
usa_medals_by_year.iloc[1:10,:]
# Out:
# Medal    Bronze  Gold  Silver
# Edition
# 1900         14    27      14
# 1904        111   146     137
# 1908         15    34      14
# 1912         31    45      25
# 1920         38   110      45
# 1924         51   110      37
# 1928         17    43      24
# 1932         59    78      44
# 1936         15    51      26

# %%
# Create the DataFrame: usa
usa = medals[medals.NOC == 'USA']

# Group usa by ['Edition', 'Medal'] and aggregate over 'Athlete'
usa_medals_by_year = usa.groupby(['Edition', 'Medal'])['Athlete'].count()

# Reshape usa_medals_by_year by unstacking
usa_medals_by_year = usa_medals_by_year.unstack(level='Medal')

# 图画要放在一张图里 才能画出来
#Plot the DataFrame usa_medals_by_year
usa_medals_by_year.plot()
plt.show()

# %% [markdown]
#  ## 作图 USA Medal Counts by Edition: Area Plot

# %%
# 建立USA的数据dataframe: Create the DataFrame: usa
usa = medals[medals.NOC == 'USA']

# 2。分组的列：加入计算的是什么： Group usa by 'Edition', 'Medal', and 'Athlete'
usa_medals_by_year = usa.groupby(['Edition', 'Medal'])['Athlete'].count()

# 3.将分组的列中的medal列展开，形成多个列Reshape usa_medals_by_year by unstacking
usa_medals_by_year = usa_medals_by_year.unstack(level='Medal')

# 4.作图Create an area plot of usa_medals_by_year
usa_medals_by_year.plot.area()
plt.show()

# %% [markdown]
# ## 定义为categorical变量后作图

# %%
# 1.更改type：针对一列Medal，其中的变量时：'Bronze', 'Silver', 'Gold'
#Redefine 'Medal' as an ordered categorical
medals.Medal = pd.Categorical(values=medals.Medal, 
                              categories=['Bronze', 'Silver', 'Gold'], 
                              ordered=True)

# 2.抽取部分的row: Create the DataFrame: usa
usa = medals[medals.NOC == 'USA']

# 3分组：Group usa by 'Edition', 'Medal', and 'Athlete'
usa_medals_by_year = usa.groupby(['Edition', 'Medal'])['Athlete'].count()

# 4.改变形状：Reshape usa_medals_by_year by unstacking
usa_medals_by_year = usa_medals_by_year.unstack(level='Medal')

# Create an area plot of usa_medals_by_year
usa_medals_by_year.plot.area()
plt.show()
